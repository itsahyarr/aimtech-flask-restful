# %%
# import libraries needed
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import joblib

# %%
df = pd.read_csv('/content/drive/MyDrive/Dataset/weight-height.csv')

# %%
df.rename(columns={'Height':'Weight','Weight':'Height'}, inplace=True) # Swapping height and weight column
df = df[['Weight','Height','Gender']]
df
# Out:
#          Weight      Height  Gender
# 0     73.847017  241.893563    Male
# 1     68.781904  162.310473    Male
# 2     74.110105  212.740856    Male
# 3     71.730978  220.042470    Male
# 4     69.881796  206.349801    Male
# ...         ...         ...     ...
# 9995  66.172652  136.777454  Female
# 9996  67.067155  170.867906  Female
# 9997  63.867992  128.475319  Female
# 9998  69.034243  163.852461  Female
# 9999  61.944246  113.649103  Female
#
# [10000 rows x 3 columns]

# %%
le = LabelEncoder()
le.fit(df['Gender'])
df['Gender'] = le.transform(df['Gender'])

# %%
df
# Out:
#          Weight      Height  Gender
# 0     73.847017  241.893563       1
# 1     68.781904  162.310473       1
# 2     74.110105  212.740856       1
# 3     71.730978  220.042470       1
# 4     69.881796  206.349801       1
# ...         ...         ...     ...
# 9995  66.172652  136.777454       0
# 9996  67.067155  170.867906       0
# 9997  63.867992  128.475319       0
# 9998  69.034243  163.852461       0
# 9999  61.944246  113.649103       0
#
# [10000 rows x 3 columns]

# %%
# Round and coverting weight & height to integer
df.round({
    'Weight':0,
    'Height':0
}).astype(int)
# Out:
#       Weight  Height  Gender
# 0         74     242       1
# 1         69     162       1
# 2         74     213       1
# 3         72     220       1
# 4         70     206       1
# ...      ...     ...     ...
# 9995      66     137       0
# 9996      67     171       0
# 9997      64     128       0
# 9998      69     164       0
# 9999      62     114       0
#
# [10000 rows x 3 columns]

# %%
predict = "Weight"

# %%
X = np.array(df.drop(labels=predict, axis=1)) # Axis=1 -> column
y = np.array(df[predict])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)
lr = LinearRegression()
model = lr.fit(X_train, y_train)
accuracy = model.score(X_test, y_test) * 100

# %%
print(f'Accuracy : {accuracy:.2f}%')
# Out:
# Accuracy : 86.74%

# %%
joblib.dump(model, 'weight-predict.joblib')
# Out:
# ['weight-predict.joblib']

# %%
# Testing model
mod = joblib.load('weight-predict.joblib')
prediction = mod.predict(X_test)
for x in range(100):
  print(prediction[x],'||',y_test[x])
# Out:
# 70.3464444855266 || 70.6060922182683
# 64.19484248868129 || 63.2179335547522
# 66.99811056295063 || 66.747293134292
# 67.5695495279614 || 67.7276312535175
# 62.72565843021654 || 62.4308668218842
# 69.75982914745214 || 69.23425085558
# 67.14316644485088 || 67.0319802933961
# 63.95877688847075 || 64.5530373378013
# 70.16580346735599 || 72.2647482777197
# 65.79916151655763 || 64.7989611645402
# 66.68371644250693 || 66.8423667997649
# 68.59314306476348 || 69.0340650960745
# 59.59759093995689 || 60.3333723850573
# 64.63372630950234 || 63.0342601763786
# 64.20756093176364 || 62.3958239669813
# 64.56586850643926 || 62.453383131306
# 71.89639110300918 || 71.9695979612664
# 72.22125341722297 || 68.9163141794859
# 64.05432136093968 || 66.5667122845471
# 69.33356725970131 || 71.0518734357455
# 67.68633557122314 || 69.2467636974264
# 60.97873233301305 || 61.3111924053438
